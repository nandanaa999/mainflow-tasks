# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('global_superstore.csv')
type(data)
pd.core.frame.DataFrame
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Sales ($)         20 non-null     float64
#  1   Profit ($)        20 non-null     float64
#  2   Region            20 non-null     object
#  3   Product Category  20 non-null     object
# dtypes: float64(2), object(2)
# memory usage: 772.0+ bytes

# %%
data.describe()
# Out:
#          Sales ($)  Profit ($)
# count    20.000000   20.000000
# mean    825.794334  118.405097
# std     524.883027  107.940068
# min      80.115089  -32.980832
# 25%     357.196118   21.117626
# 50%     732.891498  115.914836
# 75%    1263.102874  183.321697
# max    1699.569217  307.759795

# %%
data=data.drop_duplicates()
data
# Out:
#       Sales ($)  Profit ($)         Region Product Category
# 0    683.927989  176.613868  South America        Furniture
# 1   1666.823535    1.510374         Africa  Office Supplies
# 2   1293.708465   58.098021           Asia       Technology
# 3   1066.251508   85.610335  North America        Furniture
# 4    311.152199  118.865143  South America  Office Supplies
# 5    311.111052  240.864729         Europe        Furniture
# 6    144.084834   23.819071  South America        Furniture
# 7   1522.609887  140.426706         Europe        Furniture
# 8   1070.442099  169.408081         Europe        Furniture
# 9   1252.901010  -32.980832  South America       Technology
# 10    80.115089  175.016877         Africa        Furniture
# 11  1699.569217   13.013293         Europe        Furniture
# 12  1465.063901  -26.085374         Europe        Furniture
# 13   407.229289  301.551869  South America       Technology
# 14   355.175212  307.759795         Europe        Furniture
# 15   357.869753  249.472897         Europe        Furniture
# 16   564.006842   62.720324  South America       Technology
# 17   940.181997  -13.992947  South America       Technology
# 18   781.855007  203.445183  North America       Technology
# 19   541.807790  112.964529         Africa        Furniture

# %%
data.isnull()
# Out:
#     Sales ($)  Profit ($)  Region  Product Category
# 0       False       False   False             False
# 1       False       False   False             False
# 2       False       False   False             False
# 3       False       False   False             False
# 4       False       False   False             False
# 5       False       False   False             False
# 6       False       False   False             False
# 7       False       False   False             False
# 8       False       False   False             False
# 9       False       False   False             False
# 10      False       False   False             False
# 11      False       False   False             False
# 12      False       False   False             False
# 13      False       False   False             False
# 14      False       False   False             False
# 15      False       False   False             False
# 16      False       False   False             False
# 17      False       False   False             False
# 18      False       False   False             False
# 19      False       False   False             False

# %%
data.isnull().sum()
# Out:
# Sales ($)           0
# Profit ($)          0
# Region              0
# Product Category    0
# dtype: int64

# %%
data.notnull()
# Out:
#     Sales ($)  Profit ($)  Region  Product Category
# 0        True        True    True              True
# 1        True        True    True              True
# 2        True        True    True              True
# 3        True        True    True              True
# 4        True        True    True              True
# 5        True        True    True              True
# 6        True        True    True              True
# 7        True        True    True              True
# 8        True        True    True              True
# 9        True        True    True              True
# 10       True        True    True              True
# 11       True        True    True              True
# 12       True        True    True              True
# 13       True        True    True              True
# 14       True        True    True              True
# 15       True        True    True              True
# 16       True        True    True              True
# 17       True        True    True              True
# 18       True        True    True              True
# 19       True        True    True              True

# %%
data2=data.fillna(value=0)
data2
# Out:
#       Sales ($)  Profit ($)         Region Product Category
# 0    683.927989  176.613868  South America        Furniture
# 1   1666.823535    1.510374         Africa  Office Supplies
# 2   1293.708465   58.098021           Asia       Technology
# 3   1066.251508   85.610335  North America        Furniture
# 4    311.152199  118.865143  South America  Office Supplies
# 5    311.111052  240.864729         Europe        Furniture
# 6    144.084834   23.819071  South America        Furniture
# 7   1522.609887  140.426706         Europe        Furniture
# 8   1070.442099  169.408081         Europe        Furniture
# 9   1252.901010  -32.980832  South America       Technology
# 10    80.115089  175.016877         Africa        Furniture
# 11  1699.569217   13.013293         Europe        Furniture
# 12  1465.063901  -26.085374         Europe        Furniture
# 13   407.229289  301.551869  South America       Technology
# 14   355.175212  307.759795         Europe        Furniture
# 15   357.869753  249.472897         Europe        Furniture
# 16   564.006842   62.720324  South America       Technology
# 17   940.181997  -13.992947  South America       Technology
# 18   781.855007  203.445183  North America       Technology
# 19   541.807790  112.964529         Africa        Furniture

# %%
data3=data.ffill()
data
# Out:
#       Sales ($)  Profit ($)         Region Product Category
# 0    683.927989  176.613868  South America        Furniture
# 1   1666.823535    1.510374         Africa  Office Supplies
# 2   1293.708465   58.098021           Asia       Technology
# 3   1066.251508   85.610335  North America        Furniture
# 4    311.152199  118.865143  South America  Office Supplies
# 5    311.111052  240.864729         Europe        Furniture
# 6    144.084834   23.819071  South America        Furniture
# 7   1522.609887  140.426706         Europe        Furniture
# 8   1070.442099  169.408081         Europe        Furniture
# 9   1252.901010  -32.980832  South America       Technology
# 10    80.115089  175.016877         Africa        Furniture
# 11  1699.569217   13.013293         Europe        Furniture
# 12  1465.063901  -26.085374         Europe        Furniture
# 13   407.229289  301.551869  South America       Technology
# 14   355.175212  307.759795         Europe        Furniture
# 15   357.869753  249.472897         Europe        Furniture
# 16   564.006842   62.720324  South America       Technology
# 17   940.181997  -13.992947  South America       Technology
# 18   781.855007  203.445183  North America       Technology
# 19   541.807790  112.964529         Africa        Furniture

# %%
data4=data.bfill()
data4
# Out:
#       Sales ($)  Profit ($)         Region Product Category
# 0    683.927989  176.613868  South America        Furniture
# 1   1666.823535    1.510374         Africa  Office Supplies
# 2   1293.708465   58.098021           Asia       Technology
# 3   1066.251508   85.610335  North America        Furniture
# 4    311.152199  118.865143  South America  Office Supplies
# 5    311.111052  240.864729         Europe        Furniture
# 6    144.084834   23.819071  South America        Furniture
# 7   1522.609887  140.426706         Europe        Furniture
# 8   1070.442099  169.408081         Europe        Furniture
# 9   1252.901010  -32.980832  South America       Technology
# 10    80.115089  175.016877         Africa        Furniture
# 11  1699.569217   13.013293         Europe        Furniture
# 12  1465.063901  -26.085374         Europe        Furniture
# 13   407.229289  301.551869  South America       Technology
# 14   355.175212  307.759795         Europe        Furniture
# 15   357.869753  249.472897         Europe        Furniture
# 16   564.006842   62.720324  South America       Technology
# 17   940.181997  -13.992947  South America       Technology
# 18   781.855007  203.445183  North America       Technology
# 19   541.807790  112.964529         Africa        Furniture

# %%
import numpy as np
from scipy import stats
data2.columns
# Out:
# Index(['Sales ($)', 'Profit ($)', 'Region', 'Product Category'], dtype='object')

# %%
data2.drop(['Region','Product Category'],axis=1,inplace=True)
data2.columns
# Out:
# Index(['Sales ($)', 'Profit ($)'], dtype='object')

# %%
Q1=data2.quantile(0.25)
Q3=data2.quantile(0.75)
IQR=Q3-Q1
print(IQR)
# Out:
# Sales ($)     905.906756
# Profit ($)    162.204070
# dtype: float64

# %%
data2=data2[~((data2<(Q1-1.5*IQR))|(data2>(Q3+1.5*IQR))).any(axis=1)]
data2
# Out:
#       Sales ($)  Profit ($)
# 0    683.927989  176.613868
# 1   1666.823535    1.510374
# 2   1293.708465   58.098021
# 3   1066.251508   85.610335
# 4    311.152199  118.865143
# 5    311.111052  240.864729
# 6    144.084834   23.819071
# 7   1522.609887  140.426706
# 8   1070.442099  169.408081
# 9   1252.901010  -32.980832
# 10    80.115089  175.016877
# 11  1699.569217   13.013293
# 12  1465.063901  -26.085374
# 13   407.229289  301.551869
# 14   355.175212  307.759795
# 15   357.869753  249.472897
# 16   564.006842   62.720324
# 17   940.181997  -13.992947
# 18   781.855007  203.445183
# 19   541.807790  112.964529

# %%
data2.describe()
# Out:
#          Sales ($)  Profit ($)
# count    20.000000   20.000000
# mean    825.794334  118.405097
# std     524.883027  107.940068
# min      80.115089  -32.980832
# 25%     357.196118   21.117626
# 50%     732.891498  115.914836
# 75%    1263.102874  183.321697
# max    1699.569217  307.759795

# %%
plt.figure(figsize=(8,5))
plt.hist(data[['Sales ($)','Profit ($)']], bins=10, color=['skyblue','lightgreen'], edgecolor='black')
plt.title("Distribution of Sales and Profit")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
print(data.columns)
# Out:
# Index(['Sales ($)', 'Profit ($)', 'Region', 'Product Category'], dtype='object')

# %%
plt.figure(figsize=(12,6))
plt.subplot(1, 2, 1)
sns.boxplot(y=data['Sales ($)'])
plt.title('Boxplot of Sales')
plt.subplot(1, 2, 2)
sns.boxplot(y=data['Profit ($)'])
plt.show()

# %%
plt.figure(figsize=(8,6))
numeric_cols = data.select_dtypes(include=['float64', 'int64']).columns
corr = data[numeric_cols].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap of Numeric Features")
plt.show()
